# %%
import pandas as pd
import numpy as nm
import seaborn as ass
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_lifestyle_dataset.csv")

# %%
df.keys()
# Out:
# Index(['Student_ID', 'Study_Hours_Per_Day', 'Extracurricular_Hours_Per_Day',
#        'Sleep_Hours_Per_Day', 'Social_Hours_Per_Day',
#        'Physical_Activity_Hours_Per_Day', 'GPA', 'Stress_Level'],
#       dtype='object')

# %%
pizza = {
    'ГАВАЙСКАЯ': {
        'цена':{
            'мин':415,
            'макс':595,
        },
        'состав':[' Курица', 'ветчина', 'ананас',
'моцарелла', 'томатный соус'],
    },
    'ПЕППЕРОНИ': {
        'цена':{
            'мин':395,
            'макс':545,
        },
        'состав':['Пепперони', 'моцарелла',
'томатный соус'],
    },
    'МАРГАРИТА': {
        'цена':{
            'мин':395,
            'макс':545,
        },
        'состав':['Томаты', 'моцарелла',
'томатный соус'],
    },
   
}

# %%
marks = {'Mary' : [5, 8, 9, 10, 3, 5, 6, 6],
        'John' : [3, 3, 6, 8, 2, 1, 8, 5],
        'Alex' : [4, 4, 7, 4, 7, 3, 2, 9],
        'Patricia' : [2, 1, 6, 8, 2, 3, 7, 4]}

# %%
k = 1

# %%
print(round(sum([marks[i][0] for i in marks]) / len(marks)))
# Out:
# 4

# %%
from random import randint

class Item:
    def __init__(self) -> None:
        pass

class Person:
    def __init__(self) -> None:
        self.advantage = randint(0,5)
        self.helth = 100
        self.leg_lenth = 1
        self.x = randint(1,20)
        self.y = randint(1,20)

    
    def running(self, dx, dy) -> None:
        self.x += self.leg_lenth * dx
        self.y += self.leg_lenth * dy
    
    def get_item(self, item:Item) -> bool:
        pass
    
    def shooting(self) -> int:
        pass
    
    def fortuna(self) -> bool:
        pass


class Mag(Person):
    
    def __init__(self) -> None:
        super().__init__()
        self.mana = 100
    
    def spellcast(self, manacost)->int:
        if self.mana < manacost or not self.fortuna(self.advantage):
            self.helth -= 5
            print("O ГОСПОДИ БОЖЕ НЕУДАЧА, ПРОТИВОТОК МАНЫ МЕНЯ НАСТИГ!!!")
            return 0
# Out:
# {'name': 'zaza'}
